# %% [markdown]
# Connected to base (Python 3.9.7)

# %%
import yfinance as yf

dat = yf.Ticker("MSFT")
dat.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
dat.history(period='1mo')
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-05-12 00:00:00-04:00  413.584222  414.602007  405.761170  406.888702
# 2026-05-13 00:00:00-04:00  402.328624  405.431888  400.163300  404.334259
# 2026-05-14 00:00:00-04:00  403.605852  410.949931  400.013626  408.545135
# 2026-05-15 00:00:00-04:00  413.374657  427.244641  412.017611  421.008148
# 2026-05-18 00:00:00-04:00  415.719606  424.201236  414.711779  422.624664
# 2026-05-19 00:00:00-04:00  428.970892  431.764859  415.589870  416.517883
# 2026-05-20 00:00:00-04:00  413.274901  421.187755  410.411078  420.149994
# 2026-05-21 00:00:00-04:00  424.750000  426.339996  415.709991  419.089996
# 2026-05-22 00:00:00-04:00  419.540009  424.399994  416.329987  418.570007
# 2026-05-26 00:00:00-04:00  416.429993  419.769989  413.019989  416.029999
# 2026-05-27 00:00:00-04:00  411.010010  415.940002  409.579987  412.670013
# 2026-05-28 00:00:00-04:00  412.980011  429.489990  412.670013  426.989990
# ...

# %%
dat.options
# Out:
# ('2026-06-12',
#  '2026-06-15',
#  '2026-06-17',
#  '2026-06-18',
#  '2026-06-22',
#  '2026-06-26',
#  '2026-07-02',
#  '2026-07-10',
#  '2026-07-17',
#  '2026-07-24',
#  '2026-08-21',
#  '2026-09-18',
#  '2026-10-16',
#  '2026-11-20',
#  '2026-12-18',
#  '2027-01-15',
#  '2027-03-19',
#  '2027-06-17',
#  '2027-09-17',
#  '2027-12-17',
#  '2028-01-21',
#  '2028-06-16',
#  '2028-12-15')

# %%
chain = dat.option_chain('2026-06-26') # will have to change the date format, or add code to automatically convert dates into this format
chain
# Out:
# Options(calls=         contractSymbol             lastTradeDate  strike  lastPrice  bid  \
# 0   MSFT260626C00270000 2026-05-22 17:41:30+00:00   270.0     150.25  0.0
# 1   MSFT260626C00290000 2026-05-27 16:58:47+00:00   290.0     125.00  0.0
# 2   MSFT260626C00300000 2026-05-28 13:57:25+00:00   300.0     123.50  0.0
# 3   MSFT260626C00305000 2026-05-26 15:24:54+00:00   305.0     112.15  0.0
# 4   MSFT260626C00310000 2026-05-29 14:44:34+00:00   310.0     133.66  0.0
# ..                  ...                       ...     ...        ...  ...
# 58  MSFT260626C00535000 2026-06-11 18:35:09+00:00   535.0       0.10  0.0
# 59  MSFT260626C00540000 2026-06-10 16:20:55+00:00   540.0       0.12  0.0
# 60  MSFT260626C00545000 2026-06-09 17:43:00+00:00   545.0       0.06  0.0
# 61  MSFT260626C00550000 2026-06-11 19:03:43+00:00   550.0       0.04  0.0
# 62  MSFT260626C00555000 2026-06-11 19:22:02+00:00   555.0       0.07  0.0
#
# ...

# %%
calls = chain.calls
calls.head()
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice  bid  ask  \
# 0  MSFT260626C00270000 2026-05-22 17:41:30+00:00   270.0     150.25  0.0  0.0
# 1  MSFT260626C00290000 2026-05-27 16:58:47+00:00   290.0     125.00  0.0  0.0
# 2  MSFT260626C00300000 2026-05-28 13:57:25+00:00   300.0     123.50  0.0  0.0
# 3  MSFT260626C00305000 2026-05-26 15:24:54+00:00   305.0     112.15  0.0  0.0
# 4  MSFT260626C00310000 2026-05-29 14:44:34+00:00   310.0     133.66  0.0  0.0
#
#    change  percentChange  volume  openInterest  impliedVolatility  inTheMoney  \
# 0     0.0            0.0    10.0             6            0.00001        True
# 1     0.0            0.0     NaN             1            0.00001        True
# 2     0.0            0.0     1.0             2            0.00001        True
# 3     0.0            0.0     NaN             6            0.00001        True
# 4     0.0            0.0    11.0            11            0.00001        True
#
#   contractSize currency
# ...

# %%
# try with applicable data, RVMD260918C160-- 2026-09-18, 160 call
import pandas as pd

rvmd = yf.Ticker('RVMD')
chain = rvmd.option_chain('2026-09-18')
calls = chain.calls
# calls[calls['contractSymbol'] == 'RVMD260918C160'] # this doesn't work, the symbnol in the spreadsheet is different(?)

calls[calls['strike']==160]
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice  bid  \
# 21  RVMD260918C00160000 2026-06-10 17:57:13+00:00   160.0       12.1  0.0
#
#     ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 21  0.0     0.0            0.0     2.0           288            0.03126
#
#     inTheMoney contractSize currency
# 21       False      REGULAR      USD
